# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
π=np.pi

# %%
θ=np.linspace(0,2*π,500)

# %%
r=3
x=r*(np.sin(θ)-np.sin(2*θ)/2)
y=r*(np.cos(θ)-np.cos(2*θ)/2)

# %%
plt.plot(x,y)
