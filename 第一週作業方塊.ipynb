# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
π=np.pi

# %%
θ=np.linspace(0,2*π,5000)

# %%
n=3
x=np.cos(θ)+np.cos(n*θ)/n
y=np.sin(θ)-np.sin(n*θ)/n

# %%
plt.plot(x,y)
